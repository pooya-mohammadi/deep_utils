# %% [markdown]
# ## FACE DETECTION EXAMPLES
# ### This Notebook Contains This Modules For Face Detection:
# <ul>
#   <li>MTCNN For Tensorflow</li>
#   <li>MTCNN For Pytorch</li>
#   <li>SSD CV2 For Caffe</li>
#   <li>Haarcascade Cv2</li>
#   <li>Ultralight For Pytorch</li>
#   <li>Ultralight For Tensorflow</li>
# </ul>

# %%
import cv2
from deep_utils import Box, show_destroy_cv2, Point
from deep_utils import face_detector_loader
from IPython.display import Image

# %% [markdown]
# ## Select The Model You Want to Use Below

# %% [markdown]
# ### MTCNN Face Detector For Tensorflow
# #### (Activate Your Tensorflow >= 2.x Environment)

# %%
face_detector = face_detector_loader('MTCNNTFFaceDetector')
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True, confidence=0.9)
for landmarks in res['landmarks']:
    Point.put_point(img, list(landmarks.values()), radius=3)
img = Box.put_box(img, res['boxes'])
show_destroy_cv2(img)
cv2.imwrite('mtcnn-tf.jpg', img)
Image('mtcnn-tf.jpg')
# Out:
# WARNING:tensorflow:5 out of the last 24 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f38c01130d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ### MTCNN Face Detector For PyTorch
# #### (Activate Your Pytorch Environment)

# %%
face_detector = face_detector_loader('MTCNNTorchFaceDetector')
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True, confidence=0.9)
for landmarks in res['landmarks']:
    Point.put_point(img, list(landmarks.values()), radius=3)
img = Box.put_box(img, res['boxes'])
show_destroy_cv2(img)
cv2.imwrite('mtcnn-torch.jpg', img)
Image('mtcnn-torch.jpg')

# %% [markdown]
# ### SSD CV2 Face Detector For Caffe

# %%
face_detector = face_detector_loader('SSDCV2CaffeFaceDetector')
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True)
img = Box.put_box(img, res['boxes'])
show_destroy_cv2(img)
cv2.imwrite('ssd-cv2-caffe.jpg', img)
Image('ssd-cv2-caffe.jpg')

# %% [markdown]
# ### Haarcascade Cv2 Face Detector

# %%
face_detector = face_detector_loader("HaarcascadeCV2FaceDetector")
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True)
for landmarks in res['landmarks']:
    Point.put_point(img, landmarks, radius=3)
img = Box.put_box(img, res['boxes'])
show_destroy_cv2(img)
cv2.imwrite('haarcascade-cv2.jpg', img)
Image('haarcascade-cv2.jpg')

# %% [markdown]
# ### Ultralight Face Detector For PyTorch
# #### (Activate Your Pytorch Environment)

# %%
face_detector = face_detector_loader('UltralightTorchFaceDetector')
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True, confidence=0.90, net_type="RBF") # Net_type : 'RBF' or 'slim'
img = Box.put_box(img, res['boxes'])
print("boxes:", res['boxes'], "confidences: ", res['confidences'], "elapsed_time: ", res['elapsed_time'])
show_destroy_cv2(img)
cv2.imwrite('ultralight-torch.jpg', img)
Image('ultralight-torch.jpg')

# %% [markdown]
# ### Ultralight Face Detector For Tensorflow
# #### (Activate Your Tensorflow >= 2.4 Environment)

# %%
face_detector = face_detector_loader('UltralightTFFaceDetector')
img = cv2.imread('../data/movie-stars.jpg')
res = face_detector.detect_faces(img, is_rgb=False, get_time=True, confidence=0.90, net_type="RBF") # Net_type : 'RBF' or 'slim'
img = Box.put_box(img, res['boxes'])
print("boxes:", res['boxes'], "confidences: ", res['confidences'], "elapsed_time: ", res['elapsed_time'])
show_destroy_cv2(img)
cv2.imwrite('ultralight-tf.jpg', img)
Image('ultralight-tf.jpg')

# %% [markdown]
# *:)*
